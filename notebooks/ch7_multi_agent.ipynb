# %% [markdown]
# # Chapter 7: Multi-Agent Systems

# %% [markdown]
# Key Takeaways:
# - **Multi-Agent Systems** involve multiple specialized agents collaborating to achieve a complex goal.
# - **CrewAI** orchestrates these agents, managing their roles, tasks, and data flow.
# - This pattern enables **specialization**, where each agent focuses on what they do best (e.g., researching vs. writing).

# %% [markdown]
# ### Heuristic: *Divide and conquer.*

# %% [markdown]
# ## Setup and Initialization

# %%
import os
import getpass
from dotenv import load_dotenv
from crewai import Agent, Task, Crew, Process
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
# --- Configuration ---
if not os.getenv("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API key: ")

try:
    # Initializes and runs the AI crew for content creation using the latest Gemini model.
    llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
    print(f"✅ Language model initialized: {llm.model}")
except Exception as e:
    print(f"🛑 Error initializing language model: {e}")
    llm = None
# Out:
# ✅ Language model initialized: gemini-2.5-flash

# %% [markdown]
# ## Define Agents
#
# We define two specialized agents: a **Senior Research Analyst** and a **Technical Content Writer**.

# %%
# --- Define Agents ---
if llm:
    # Researcher Agent
    researcher = Agent(
        role='Senior Research Analyst',
        goal='Find and summarize the latest trends in AI.',
        backstory="You are an experienced research analyst with a knack for identifying key trends and synthesizing information.",
        verbose=True,
        allow_delegation=False,
        llm=llm
    )

    # Writer Agent
    writer = Agent(
        role='Technical Content Writer',
        goal='Write a clear and engaging blog post based on research findings.',
        backstory="You are a skilled writer who can translate complex technical topics into accessible content.",
        verbose=True,
        allow_delegation=False,
        llm=llm
    )

# %% [markdown]
# ## Define Tasks
#
# The researcher finds the trends, and the writer creates the content based on those findings.

# %%
# --- Define Tasks ---

# Research Task
research_task = Task(
    description="Research the top 3 emerging trends in Artificial Intelligence in 2024-2025. Focus on practical applications and potential impact.",
    expected_output="A detailed summary of the top 3 AI trends, including key points and sources.",
    agent=researcher,
)

# Writing Task
writing_task = Task(
    description="Write a 500-word blog post based on the research findings. The post should be engaging and easy for a general audience to understand.",
    expected_output="A complete 500-word blog post about the latest AI trends.",
    agent=writer,
    context=[research_task], # This explicitly passes the research output to the writer
)

# %% [markdown]
# ## Execution
#
# We group the agents into a `Crew` and execute the process sequentially.

# %%
# --- Execute Crew ---
if llm:
    # Create the Crew
    blog_creation_crew = Crew(
        agents=[researcher, writer],
        tasks=[research_task, writing_task],
        process=Process.sequential,
        verbose=True # Set verbosity for detailed crew execution logs
    )

    print("## Running the blog creation crew with Gemini 2.0 Flash... ##")
    try:
        result = blog_creation_crew.kickoff()
        print("\n\n---\n## Crew Final Output ##\n---")
        print(result)
    except Exception as e:
        print(f"\nAn unexpected error occurred: {e}")
# Out:
# ## Running the blog creation crew with Gemini 2.0 Flash... ##
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: febcd7ad-0077-498c-846b-d14ace8ac1e7                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Research Analyst                                                                                 │
# │                                                                                                                 │
# │  Task: Research the top 3 emerging trends in Artificial Intelligence in 2024-2025. Focus on practical           │
# │  applications and potential impact.                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 8a62de59-0a3b-4297-af8b-6477f1b241a1                                                                     │
# │  Agent: Senior Research Analyst                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technical Content Writer                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ## The AI Revolution is Here: Top 3 Trends Shaping Our Future in 2024-2025                                     │
# │                                                                                                                 │
# │  Artificial Intelligence isn't just a buzzword anymore; it's a rapidly evolving force reshaping industries,     │
# │  experiences, and our daily lives. As we move into 2024 and 2025, AI is becoming more sophisticated,            │
# │  autonomous, and accessible than ever before. Forget the sci-fi movies for a moment – let's dive into the       │
# │  three most exciting and impactful AI trends poised to redefine our world, making complex tasks simpler and     │
# │  unleashing unprecedented innovation.                                                                           │
# │                                                                                                                 │
# │  ### 1. Advanced Generative AI & Multimodality: Beyond Text and Images                                          │
# │                                                                                                                 │
# │  Remember when AI could only generate text, or maybe a simple image? Get ready for "multimodal" magic. This     │
# │  trend signifies a leap where AI can now understand, interpret, and create content across *everything* – text,  │
# │  images, audio, video, even 3D models and code – all at once! Imagine feeding an AI a simple text brief for a   │
# │  product launch and receiving a complete video ad, social media graphics, and website copy, all perfectly       │
# │  tailored.                                                                                                      │
# │                                                                                                                 │
# │  This isn't just about making pretty pictures; it's about hyper-personalized content creation, accelerating     │
# │  scientific discovery (like generating new drug compounds), or even helping developers write complex code from  │
# │  a simple description. The impact? A massive boost in productivity for creative industries, highly customized   │
# │  experiences for everyone, and entirely new forms of digital art. Of course, this power also brings challenges  │
# │  around deepfakes and intellectual property, but the creative potential is undeniable.                          │
# │                                                                                                                 │
# │  ### 2. AI Agents & Autonomous Systems: Proactive Problem Solvers                                               │
# │                                                                                                                 │
# │  Beyond simply responding to commands, AI is evolving into proactive "agents" – systems that can understand     │
# │  high-level goals, break them down into sub-tasks, plan and execute sequences of actions, and learn from        │
# │  feedback, all with minimal human help. Think of it as a super-smart digital assistant that doesn't just        │
# │  answer questions, but *manages* your entire international trip, from booking flights and hotels to planning    │
# │  activities across multiple platforms.                                                                          │
# │                                                                                                                 │
# │  In business, these agents could autonomously manage intricate supply chains, optimizing logistics in           │
# │  real-time, or even handling end-to-end customer service inquiries, including proactive outreach. On the        │
# │  factory floor, robots become more intelligent, adapting to changing conditions and collaborating safely with   │
# │  humans. The promise here is hyper-automation, freeing us from routine, repetitive tasks to focus on            │
# │  creativity and strategy. However, ensuring safety, ethical deployment, and transparent accountability for      │
# │  these autonomous systems will be crucial.                                                                      │
# │                                                                                                                 │
# │  ### 3. Efficient AI & Edge Computing: AI Everywhere, Faster, and More Private                                  │
# │                                                                                                                 │
# │  While giant AI models get a lot of headlines, another crucial trend is making AI more practical and            │
# │  widespread: "Efficient AI" and "Edge Computing." This means bringing AI processing power *directly* to the     │
# │  devices we use every day – our smartphones, smartwatches, industrial machinery, or autonomous vehicles –       │
# │  instead of relying solely on distant cloud data centers. This includes the rise of "Small Language Models"     │
# │  (SLMs) that are specialized, faster, and less resource-hungry.                                                 │
# │                                                                                                                 │
# │  The benefits are huge: instant responses (think self-driving cars reacting in milliseconds), enhanced privacy  │
# │  (your data stays on your device), and the ability to use advanced AI in remote areas without internet          │
# │  connectivity. Imagine your phone translating languages in real-time, offline, or factory sensors predicting    │
# │  equipment failure instantly without sending sensitive data to the cloud. This trend democratizes AI, makes it  │
# │  more sustainable, and opens up new possibilities for innovation in countless devices.                          │
# │                                                                                                                 │
# │  ### The Future is Now                                                                                          │
# │                                                                                                                 │
# │  From AI that creates multimodal masterpieces to autonomous agents managing complex operations and efficient    │
# │  AI running on the smallest devices, the future of artificial intelligence is here and it's incredibly          │
# │  dynamic. These trends promise to unlock unprecedented levels of productivity, personalization, and innovation  │
# │  across every sector. Staying informed about these shifts isn't just for tech enthusiasts; it's essential for   │
# │  anyone looking to understand and thrive in the world of tomorrow. The AI revolution isn't coming; it's         │
# │  already unfolding all around us.                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---
# ## Crew Final Output ##
# ---
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 80c24a60-1904-4e0a-be2f-1ac470b02eba                                                                     │
# │  Agent: Technical Content Writer                                                                                │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Conclusion
#
# By decomposing a workflow into specialized roles (Research -> Writing), we can achieve higher quality outputs than a single prompt might produce. The multi-agent approach mimics a real-world editorial team.
